# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as mp

# %%
data = pd.read_excel('TV_Set 77 - Copy.xlsx')

# %%
data

# %%
X = data.iloc[:, 1:12]
X

# %%
y = data['2-class']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score
from numpy import mean
from numpy import std

# %%
cv = RepeatedKFold(n_splits=10, n_repeats=15, random_state=1)

# %%
model = RandomForestClassifier()

# %%
scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
scores

# %%
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))

# %%
test = pd.read_excel('Test Set 20.xlsx')
test.head()

# %%
X_test = test.iloc[:, 1:12]

# %%
y_test  = test['2-class']

# %%
model.fit(X,y)

# %%
y_pred =model.predict(X_test)

# %%
y_pred

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)

# %%
from sklearn.metrics import f1_score
f1_score(y_test, y_pred, average='weighted')

# %%
mp.figure(figsize=(15,15))
dataplot = sn.heatmap(data.corr(), cmap="Greens", annot=True)

mp.show()
# Out:
# C:\temp\ipykernel_10652\470709970.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataplot = sn.heatmap(data.corr(), cmap="Greens", annot=True)
