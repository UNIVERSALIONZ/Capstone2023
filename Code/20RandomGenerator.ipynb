# %%
import pandas as pd
import random

# %%
dataset = pd.read_excel('TotalDataset_modified.xlsx')

# %%
dataset
# Out:
#        pdb  Hbond  Hphob  consurf  3-class  2-class    asa  Number of atoms  \
# 0     1a22      0      0        8        0      0.0  2.089               11
# 1     1a22      3      0        4        0      0.0  0.637               11
# 2     1a22      0      0        5        0      0.0  0.226                7
# 3     1a22      3      0        5        0      0.0  0.138                6
# 4     1a22      0      0        4        0      0.0  0.478               11
# ...    ...    ...    ...      ...      ...      ...    ...              ...
# 1041  6CE9      2      0        9        2      1.0  0.034                4
# 1042  6CE9      1      0        7        0      0.0  0.394                4
# 1043  6CE9      0      0        3        0      0.0  1.588                9
# 1044  6CE9      1      1        9        2      1.0  0.369               11
# 1045  6CE9      1      0        9        2      1.0  0.222                7
#
#       Number of electrostatic charge  Number of potential hydrogen bonds  \
# 0                                  0                                   2
# 1                                  1                                   4
# 2                                  0                                   2
# 3                                  0                                   4
# 4                                  1                                   4
# ...                              ...                                 ...
# 1041                               0                                   2
# 1042                               0                                   2
# 1043                              -1                                   4
# 1044                               0                                   2
# 1045                               0                                   2
#
#       Hydrophobicity  Hydrophilicity  Propensity  Isoelectric points   Mass  \
# 0               0.61            -2.5        0.82               5.755  147.2
# 1              -1.76            -0.5        0.27               5.405  156.2
# 2              -0.07             0.0       -0.25               6.295   97.1
# 3              -0.26             0.3       -0.33               5.700   87.1
# 4              -1.76            -0.5        0.27               5.405  156.2
# ...              ...             ...         ...                 ...    ...
# 1041            0.16             0.0       -0.07               6.065   57.0
# 1042            0.16             0.0       -0.07               6.065   57.0
# 1043           -0.62             3.0       -0.13               5.785  129.1
# 1044            0.61            -2.5        0.82               5.755  147.2
# 1045            0.54            -1.5        0.27               6.015   99.1
#
#       Expected number of contacts within 14 Å sphere   \
# 0                                                5.27
# 1                                               -0.93
# 2                                               -3.03
# 3                                               -2.84
# 4                                               -0.93
# ...                                               ...
# 1041                                            -1.62
# 1042                                            -1.62
# 1043                                            -3.64
# 1044                                             5.27
# 1045                                             4.45
#
#       Electron-ion interaction potential
# 0                                 0.0946
# 1                                 0.0959
# 2                                 0.0198
# 3                                 0.0829
# 4                                 0.0959
# ...                                  ...
# 1041                              0.0050
# 1042                              0.0050
# 1043                              0.0058
# 1044                              0.0946
# 1045                              0.0057
#
# [1046 rows x 17 columns]

# %%
arr = dataset.pdb.unique()
arr = list(arr)

# %%
w= random.sample(arr, 20)
w
# Out:
# ['1fcc',
#  '1YCS',
#  '2F6A',
#  '1F47',
#  '2c0l',
#  '2j1k',
#  '2ftl',
#  '1a4y',
#  '3bk3',
#  '1tm1',
#  '4WHD',
#  '2i9b',
#  '1jtg',
#  '1lfd',
#  '1NMB',
#  '1QZ2',
#  '3K2M',
#  '1NFI',
#  '1NRR',
#  '3nps']

# %%
X = dataset.iloc[:, 1:7]

# %%
y = dataset['3-class']

# %%
y

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
model.fit(X,y)

# %%
test = pd.read_excel('Test1.xlsx')
test.head()

# %%
X_test = test.iloc[:, 1:7]

# %%
y_test  = test['3-class']

# %%
y_pred =model.predict(X_test)

# %%
y_pred

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)

# %%
from sklearn.metrics import f1_score
f1_score(y_test, y_pred, average='weighted')
